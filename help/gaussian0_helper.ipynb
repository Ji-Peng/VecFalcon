# %%
GAUSS0 = [
    [10745844, 3068844, 3741698],
    [5559083, 1580863, 8248194],
    [2260429, 13669192, 2736639],
    [708981, 4421575, 10046180],
    [169348, 7122675, 4136815],
    [30538, 13063405, 7650655],
    [4132, 14505003, 7826148],
    [417, 16768101, 11363290],
    [31, 8444042, 8086568],
    [1, 12844466, 265321],
    [0, 1232676, 13644283],
    [0, 38047, 9111839],
    [0, 870, 6138264],
    [0, 14, 12545723],
    [0, 0, 3104126],
    [0, 0, 28824],
    [0, 0, 198],
    [0, 0, 1]
]

GAUSS0_72b = []

for i, (a, b, c) in enumerate(GAUSS0):
    value = (a << 48) + (b << 24) + c
    GAUSS0_72b.append(value)

print(GAUSS0_72b)

for i, value in enumerate(GAUSS0_72b):
    high_8bits = (value >> 64) & 0xFF  # 确保只取 8 位
    low_64bits = value & 0xFFFFFFFFFFFFFFFF
    # print(f"GAUSS0_72b[{i:2d}] = {value}")
    print(f"{i:2d}: {high_8bits}, {low_64bits}")
# Out:
# [3024686241123004913666, 1564742784480091954050, 636254429462080897535, 199560484645026482916, 47667343854657281903, 8595902006365044063, 1163297957344668388, 117656387352093658, 8867391802663976, 496969357462633, 20680885154299, 638331848991, 14602316184, 247426747, 3104126, 28824, 198, 1]
#  0: 163, 17866957108348000258
#  1: 84, 15216282288489618306
#  2: 34, 9065130955956142591
#  3: 10, 15093043907930966756
#  4: 2, 10773855707238178671
#  5: 0, 8595902006365044063
#  6: 0, 1163297957344668388
#  7: 0, 117656387352093658
#  8: 0, 8867391802663976
#  9: 0, 496969357462633
# 10: 0, 20680885154299
# 11: 0, 638331848991
# 12: 0, 14602316184
# 13: 0, 247426747
# 14: 0, 3104126
# 15: 0, 28824
# 16: 0, 198
# 17: 0, 1
